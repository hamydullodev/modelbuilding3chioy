# %%
class Ozim:
    def __init__(self, name, height, weight, age, country):
        self.name = name
        self.height = height
        self.weight = weight
        self.age = age
        self.country = country

    def info(self):
        return f"Ism: {self.name}, Yosh: {self.age}, Bo‘y: {self.height} cm, Vazn: {self.weight} kg, Davlat: {self.country}"

# %%
men = Ozim("Hamidullo", 175, 68, 20, "Uzbekistan")
print(men.info())
# Out:
# Ism: Hamidullo, Yosh: 20, Bo‘y: 175 cm, Vazn: 68 kg, Davlat: Uzbekistan

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/abduroshyd/Downloads/artworks 1m above/artworks_piccaso4.csv')

# %%
df.head(10)
# Out:
#                              title                           artist  \
# 0                         Étreinte  PABLO PICASSO (b. 1881 d. 1973)
# 1           Femme dans un fauteuil  PABLO PICASSO (b. 1881 d. 1973)
# 2  Portrait de femme endormie. iii  PABLO PICASSO (b. 1881 d. 1973)
# 3     Femme assise en costume vert  PABLO PICASSO (b. 1881 d. 1973)
# 4     Baigneuse et cabine de bains  PABLO PICASSO (b. 1881 d. 1973)
# 5                         Nu assis  PABLO PICASSO (b. 1881 d. 1973)
# 6            Buste de femme assise  PABLO PICASSO (b. 1881 d. 1973)
# 7                  Homme � la pipe  PABLO PICASSO (b. 1881 d. 1973)
# 8                          Diurnes  PABLO PICASSO (b. 1881 d. 1973)
# 9                  Tête à l'oiseau  PABLO PICASSO (b. 1881 d. 1973)
#
#                                 description purchase_price sale_price  \
# 0  white wax crayon and pencil on red paper          $114K      $4.9M
# 1                             oil on canvas          $468K     $17.2M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   title                          246 non-null    object
#  1   artist                         246 non-null    object
#  2   description                    245 non-null    object
#  3   purchase_price                 246 non-null    object
#  4   sale_price                     246 non-null    object
#  5   gross_appreciation_multiplier  246 non-null    object
#  6   gross_appreciation_period      246 non-null    object
#  7   url                            246 non-null    object
#  8   has_image                      246 non-null    bool
#  9   image_url                      240 non-null    object
# dtypes: bool(1), object(9)
# memory usage: 17.7+ KB

# %%
for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=='object':
                df[col].fillna(df[col].mode()[0],inplace=True)
            else:
                df[col].fillna(df[col].mean(),inplace=True)
# Out:
# /var/folders/wh/dy7k6khj2rl3tts1n3g7lzn40000gn/T/ipykernel_6816/2286963672.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
def encodla(df):
    encoder=LabelEncoder()
    for col in df.columns:
        if df[col].dtype=='object':
            if df[col].nunique()<=5:
                dummies=pd.get_dummies(df[col],prefix=col,dtype=int)
                df=pd.concat([df.drop(columns=col),dummies],axis=1)
            else:
                df[col]=encoder.fit_transform(df[col])
    return df

# %%
df=encodla(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 10 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   title                                   246 non-null    int64
#  1   description                             246 non-null    int64
#  2   purchase_price                          246 non-null    int64
#  3   sale_price                              246 non-null    int64
#  4   gross_appreciation_multiplier           246 non-null    int64
#  5   gross_appreciation_period               246 non-null    int64
#  6   url                                     246 non-null    int64
#  7   has_image                               246 non-null    bool
#  8   image_url                               246 non-null    int64
#  9   artist_PABLO PICASSO (b. 1881 d. 1973)  246 non-null    int64
# dtypes: bool(1), int64(9)
# memory usage: 17.7 KB

# %%
df.head(20)
# Out:
#     title  description  purchase_price  sale_price  \
# 0     206          134              19         107
# 1      57           85             143          42
# 2     164           47              79         185
# 3      52           84             180          63
# 4      18          114              72         144
# 5     140           85              71         125
# 6      26           85             157          13
# 7      88           82             219          32
# 8      42          133             121         161
# 9     196           86              37          55
# 10     46           85             108         106
# 11     54           85             193          11
# 12    108          102              61          57
# 13    116           85              99          84
# 14     34          116               3          41
# 15     23           88              28           4
# 16     29           85             218         186
# ...

# %%
from sklearn.preprocessing import StandardScaler
def scale_qil(df):
    scaler=StandardScaler()
    for col in df.columns:
        num_col=df.select_dtypes(include=['int64','float64']).columns.drop('artist_PABLO PICASSO (b. 1881 d. 1973)')
        df[num_col]=scaler.fit_transform(df[num_col])
    return df

# %%
scale_qil(df)
# Out:
#         title  description  purchase_price  sale_price  \
# 0    1.689924     1.749189       -1.435347    0.309148
# 1   -0.787577     0.295271        0.414413   -0.796237
# 2    0.991568    -0.832258       -0.540302    1.635610
# 3   -0.870714     0.265599        0.966358   -0.439112
# 4   -1.436050     1.155753       -0.644724    0.938368
# ..        ...          ...             ...         ...
# 241  0.575880    -1.781756       -0.913237   -1.493480
# 242 -0.105848    -1.425694        0.369661   -0.405100
# 243 -1.602325     1.185425        1.712228    0.173101
# 244 -1.585697     1.185425        0.011643   -1.119349
# 245 -1.552442    -2.108145       -0.167366   -1.306414
#
#      gross_appreciation_multiplier  gross_appreciation_period       url  \
# 0                         1.531549                   1.490648  1.133587
# 1                         1.197921                   0.978498 -0.753378
# 2                         1.150260                  -0.131160  0.964605
# ...

# %%
df.head(15)
# Out:
#        title  description  purchase_price  sale_price  \
# 0   1.689924     1.749189       -1.435347    0.309148
# 1  -0.787577     0.295271        0.414413   -0.796237
# 2   0.991568    -0.832258       -0.540302    1.635610
# 3  -0.870714     0.265599        0.966358   -0.439112
# 4  -1.436050     1.155753       -0.644724    0.938368
# 5   0.592507     0.295271       -0.659641    0.615255
# 6  -1.303030     0.295271        0.623257   -1.289409
# 7  -0.272124     0.206255        1.548137   -0.966296
# 8  -1.036989     1.719517        0.086230    1.227468
# 9   1.523648     0.324942       -1.166833   -0.575160
# 10 -0.970479     0.295271       -0.107696    0.292142
# 11 -0.837459     0.295271        1.160284   -1.323420
# 12  0.060427     0.799691       -0.808815   -0.541148
# 13  0.193447     0.295271       -0.241953   -0.081988
# 14 -1.170010     1.215096       -1.674025   -0.813243
#
#     gross_appreciation_multiplier  gross_appreciation_period       url  \
# ...

# %%
print(df.columns)
# Out:
# Index(['title', 'description', 'purchase_price', 'sale_price',
#        'gross_appreciation_multiplier', 'gross_appreciation_period', 'url',
#        'has_image', 'image_url', 'artist_PABLO PICASSO (b. 1881 d. 1973)'],
#       dtype='object')

# %%
y=df['artist_PABLO PICASSO (b. 1881 d. 1973)']

# %%
x=df.drop('artist_PABLO PICASSO (b. 1881 d. 1973)',axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test = train_test_split(x, test_size=0.3)
y_train, y_test = train_test_split(y, test_size=0.3)

# %%
x_train.shape
# Out:
# (172, 9)

# %%
x_test.shape
# Out:
# (74, 9)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
rf=RandomForestClassifier()
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(y_test,y_pred)
print(score)
# Out:
# 1.0

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
scor=accuracy_score(y_test,y_pred)
print(scor)
# Out:
# 1.0

# %%
from tabulate import tabulate

# %%
results=[

['Decision Tree',1.0],
['Random Forest',1.0]
]


headers=['Algorithm','Accuracy_score']

table=tabulate(results, headers=headers, tablefmt='grid',floatfmt='.2f')

print(table)
# Out:
# +---------------+------------------+
# | Algorithm     |   Accuracy_score |
# +===============+==================+
# | Decision Tree |             1.00 |
# +---------------+------------------+
# | Random Forest |             1.00 |
# +---------------+------------------+

# %%
df.head(10)
# Out:
#       title  description  purchase_price  sale_price  \
# 0  1.689924     1.749189       -1.435347    0.309148
# 1 -0.787577     0.295271        0.414413   -0.796237
# 2  0.991568    -0.832258       -0.540302    1.635610
# 3 -0.870714     0.265599        0.966358   -0.439112
# 4 -1.436050     1.155753       -0.644724    0.938368
# 5  0.592507     0.295271       -0.659641    0.615255
# 6 -1.303030     0.295271        0.623257   -1.289409
# 7 -0.272124     0.206255        1.548137   -0.966296
# 8 -1.036989     1.719517        0.086230    1.227468
# 9  1.523648     0.324942       -1.166833   -0.575160
#
#    gross_appreciation_multiplier  gross_appreciation_period       url  \
# 0                       1.531549                   1.490648  1.133587
# 1                       1.197921                   0.978498 -0.753378
# 2                       1.150260                  -0.131160  0.964605
# 3                       1.102599                   0.807781 -0.851951
# ...

# %%
df['avarage gross']=df['gross_appreciation_multiplier']+df['gross_appreciation_period']

# %%
df['comment']=df['title']+df['description']

# %%
df['profit']=df['sale_price']-df['purchase_price']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   title                                   246 non-null    float64
#  1   description                             246 non-null    float64
#  2   purchase_price                          246 non-null    float64
#  3   sale_price                              246 non-null    float64
#  4   gross_appreciation_multiplier           246 non-null    float64
#  5   gross_appreciation_period               246 non-null    float64
#  6   url                                     246 non-null    float64
#  7   has_image                               246 non-null    bool
#  8   image_url                               246 non-null    float64
#  9   artist_PABLO PICASSO (b. 1881 d. 1973)  246 non-null    int64
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
rf=RandomForestClassifier()
dt=DecisionTreeClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
sc=accuracy_score(y_test,y_pred)
print(sc)
# Out:
# 1.0

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
scr=accuracy_score(y_test,y_pred)
print(scr)
# Out:
# 1.0
